# %%
import numpy as np
import matplotlib.pyplot as plt

import matplotlib.font_manager as fm
import os


data_U_mag = np.loadtxt('U_mag_ratio0.5.txt')
data_U_x = np.loadtxt('U_x_ratio0.5.txt')
data_U_y = np.loadtxt('U_y_ratio0.5.txt')
data_U_z = np.loadtxt('U_z_ratio0.5.txt')

data_direct = np.loadtxt('U_direct0.5.txt')


#data_U_0 = np.loadtxt('U_0-0.5.txt')
data_U_0_05 = np.loadtxt('U_0-0.5.txt')

data_U_0_10 = np.loadtxt('U_0-10.txt')




'''
data_U_mag = np.loadtxt('U_mag_ratio1.txt')
data_U_x = np.loadtxt('U_x_ratio1.txt')
data_U_y = np.loadtxt('U_y_ratio1.txt')
data_U_z = np.loadtxt('U_z_ratio1.txt')

'''


data_measured_velocity_ratio = np.loadtxt('realprofile_fig5_6_data/fig5abc.txt')
data_measured_velocity_direction = np.loadtxt('realprofile_fig5_6_data/fig6abc.txt')
data_measured_velocity_direction_deviation = np.loadtxt('realprofile_fig5_6_data/fig6def.txt')

# %%
data_U_mag
# Out:
# array([[2.93244041, 1.79558772, 1.63313682],
#        [2.87525583, 1.7898308 , 1.60644002],
#        [2.70629992, 1.76569471, 1.53271112],
#        [2.47427611, 1.72478734, 1.43453981],
#        [2.1792594 , 1.65702975, 1.31516009],
#        [2.02112121, 1.61952311, 1.24797306],
#        [1.87782694, 1.58110345, 1.18766861],
#        [1.63605512, 1.5024398 , 1.08893222],
#        [1.40481664, 1.37646591, 1.02059675],
#        [1.18980721, 1.24770688, 0.95359513],
#        [1.04696981, 1.20540447, 0.86856307]])

# %%
U_top_to_bottom_mag=data_U_mag[:,0]
U_top_to_mid_mag=data_U_mag[:,1]
U_mid_to_bottom_mag=data_U_mag[:,2]

U_top_to_bottom_x=data_U_mag[:,0]
U_top_to_mid_x=data_U_mag[:,1]
U_mid_to_bottom_x=data_U_mag[:,2]

U_top_to_bottom_y=data_U_mag[:,0]
U_top_to_mid_y=data_U_mag[:,1]
U_mid_to_bottom_y=data_U_mag[:,2]

U_top_to_bottom_z=data_U_mag[:,0]
U_top_to_mid_z=data_U_mag[:,1]
U_mid_to_bottom_z=data_U_mag[:,2]

# %%
U_top_to_bottom_mag
# Out:
# array([2.93244041, 2.87525583, 2.70629992, 2.47427611, 2.1792594 ,
#        2.02112121, 1.87782694, 1.63605512, 1.40481664, 1.18980721,
#        1.04696981])

# %%
angle=[0,10,20,30,40,45,50,60,70,80,89]
#angle=[0,10,20,30,40,45,50,60,70,80,90]
#angle=[0,10,20,30,40,45,50,60]
#angle=[0,10,20,30,40,45,50,60,70,90]
#angle=[10,20,30,45,50,60,70,80,90]

angle
# Out:
# [0, 10, 20, 30, 40, 45, 50, 60, 70, 80, 89]

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the X_label versus Y_label for different changed_parameter
ax.plot(angle,data_U_mag[:,0], 'bo-')
    

font_properties = fm.FontProperties(
    family='serif',  # Specify the font family
    style='italic',
    size=12,
    weight='bold'  # Specify the font weight (e.g., 'normal', 'bold')
)


ax.set_xlabel('Inlet velocity angle', fontproperties=font_properties)
ax.set_ylabel('Velocity magnitude ratio', fontproperties=font_properties)
#ax.set_title(f'{fixed_parameter1}={fixed_parameter1_value} and {fixed_parameter2}={fixed_parameter2_value} for Different {changed_parameter} prob 3 to 1')

# Define custom x-axis tick positions and labels
x_tick_positions = list(range(0,91,5))  # Specify the tick positions
x_tick_labels = [str(x) for x in x_tick_positions]  # Convert positions to strings
ax.set_xticks(x_tick_positions)
ax.set_xticklabels(x_tick_labels)


# Define custom y-axis tick positions and labels
y_tick_positions = list(np.arange(0,4,0.5))  # Specify the tick positions
y_tick_labels = [str(y) for y in y_tick_positions]  # Convert positions to strings
ax.set_yticks(y_tick_positions)
ax.set_yticklabels(y_tick_labels)


y_min=0.5
y_max=3.5
ax.set_ylim(y_min, y_max)


# Set font size for axis tick labels (both x and y)
tick_font_size = 14  # Adjust the font size as needed
ax.tick_params(axis='both', labelsize=tick_font_size)



ax.legend(prop=font_properties)
# Turn off the legend frame
ax.get_legend().set_frame_on(False)

# Adjust space between subplots
# plt.tight_layout()

plt.grid(True)

plt.savefig('U_mag_up_to_bottom.png')


#save_path = os.path.join('result_prob_H3_angle_H3_all',f'H3_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#save_path = os.path.join(save_file,f'{changed_parameter}_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#plt.savefig(save_path)

# Show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# plt.plot(angle,data_U_mag[:,0], 'bo--')
#
# #plt.xlabel('time (s)', fontdict=font)
# plt.xlabel("angle (degree)")
#
# plt.ylabel("U_mag: Up/bottom")
#
# plt.yticks(np.arange(min(data_U_mag[:,0]), 1.1*max(data_U_mag[:,0]), 0.25))
#
# plt.xticks(np.arange(min(angle), max(angle)+10, 5))
#
#
# #plt.grid()
#
# plt.grid(axis = 'y')
#
# plt.savefig('U_mag_up_to_bottom.png')
#
# plt.show()
#
#
# data_U_mag[:,0]

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the X_label versus Y_label for different changed_parameter
ax.plot(angle,data_U_mag[:,1], 'bo-')
    

font_properties = fm.FontProperties(
    family='serif',  # Specify the font family
    style='italic',
    size=12,
    weight='bold'  # Specify the font weight (e.g., 'normal', 'bold')
)


ax.set_xlabel('Inlet velocity angle', fontproperties=font_properties)
ax.set_ylabel('Velocity magnitude ratio', fontproperties=font_properties)
#ax.set_title(f'{fixed_parameter1}={fixed_parameter1_value} and {fixed_parameter2}={fixed_parameter2_value} for Different {changed_parameter} prob 3 to 1')

# Define custom x-axis tick positions and labels
x_tick_positions = list(range(0,91,5))  # Specify the tick positions
x_tick_labels = [str(x) for x in x_tick_positions]  # Convert positions to strings
ax.set_xticks(x_tick_positions)
ax.set_xticklabels(x_tick_labels)


# Define custom y-axis tick positions and labels
y_tick_positions = list(np.arange(0,2,0.25))  # Specify the tick positions
y_tick_labels = [str(y) for y in y_tick_positions]  # Convert positions to strings
ax.set_yticks(y_tick_positions)
ax.set_yticklabels(y_tick_labels)


y_min=1
y_max=2
ax.set_ylim(y_min, y_max)


# Set font size for axis tick labels (both x and y)
tick_font_size = 14  # Adjust the font size as needed
ax.tick_params(axis='both', labelsize=tick_font_size)



ax.legend(prop=font_properties)
# Turn off the legend frame
ax.get_legend().set_frame_on(False)

# Adjust space between subplots
#plt.tight_layout()

plt.grid(True)


plt.savefig('U_mag_up_to_mid.png')


#save_path = os.path.join('result_prob_H3_angle_H3_all',f'H3_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#save_path = os.path.join(save_file,f'{changed_parameter}_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#plt.savefig(save_path)

# Show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the X_label versus Y_label for different changed_parameter
ax.plot(angle,data_U_mag[:,2], 'bo-')
    

font_properties = fm.FontProperties(
    family='serif',  # Specify the font family
    style='italic',
    size=12,
    weight='bold'  # Specify the font weight (e.g., 'normal', 'bold')
)


ax.set_xlabel('Inlet velocity angle', fontproperties=font_properties)
ax.set_ylabel('Velocity magnitude ratio', fontproperties=font_properties)
#ax.set_title(f'{fixed_parameter1}={fixed_parameter1_value} and {fixed_parameter2}={fixed_parameter2_value} for Different {changed_parameter} prob 3 to 1')

# Define custom x-axis tick positions and labels
x_tick_positions = list(range(0,91,5))  # Specify the tick positions
x_tick_labels = [str(x) for x in x_tick_positions]  # Convert positions to strings
ax.set_xticks(x_tick_positions)
ax.set_xticklabels(x_tick_labels)


# Define custom y-axis tick positions and labels
y_tick_positions = list(np.arange(0,2,0.25))  # Specify the tick positions
y_tick_labels = [str(y) for y in y_tick_positions]  # Convert positions to strings
ax.set_yticks(y_tick_positions)
ax.set_yticklabels(y_tick_labels)


y_min=0.8
y_max=2
ax.set_ylim(y_min, y_max)


# Set font size for axis tick labels (both x and y)
tick_font_size = 14  # Adjust the font size as needed
ax.tick_params(axis='both', labelsize=tick_font_size)



ax.legend(prop=font_properties)
# Turn off the legend frame
ax.get_legend().set_frame_on(False)

# Adjust space between subplots
#plt.tight_layout()

plt.grid(True)


plt.savefig('U_mag_mid_to_bottom.png')


#save_path = os.path.join('result_prob_H3_angle_H3_all',f'H3_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#save_path = os.path.join(save_file,f'{changed_parameter}_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#plt.savefig(save_path)

# Show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## velocity direction

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the X_label versus Y_label for different changed_parameter
ax.plot(angle,abs(data_direct[:,0]), 'bo--')
ax.plot(angle,angle, 'r-')


font_properties = fm.FontProperties(
    family='serif',  # Specify the font family
    style='italic',
    size=12,
    weight='bold'  # Specify the font weight (e.g., 'normal', 'bold')
)


ax.set_xlabel('Inlet velocity angle', fontproperties=font_properties)
ax.set_ylabel('Probe velocity direction', fontproperties=font_properties)
#ax.set_title(f'{fixed_parameter1}={fixed_parameter1_value} and {fixed_parameter2}={fixed_parameter2_value} for Different {changed_parameter} prob 3 to 1')

# Define custom x-axis tick positions and labels
x_tick_positions = list(range(0,91,5))  # Specify the tick positions
x_tick_labels = [str(x) for x in x_tick_positions]  # Convert positions to strings
ax.set_xticks(x_tick_positions)
ax.set_xticklabels(x_tick_labels)


# Define custom y-axis tick positions and labels
y_tick_positions = list(np.arange(0,91,5))  # Specify the tick positions
y_tick_labels = [str(y) for y in y_tick_positions]  # Convert positions to strings
ax.set_yticks(y_tick_positions)
ax.set_yticklabels(y_tick_labels)


y_min=0
y_max=90
ax.set_ylim(y_min, y_max)


# Set font size for axis tick labels (both x and y)
tick_font_size = 14  # Adjust the font size as needed
ax.tick_params(axis='both', labelsize=tick_font_size)



ax.legend(prop=font_properties)
# Turn off the legend frame
ax.get_legend().set_frame_on(False)

# Adjust space between subplots
# plt.tight_layout()

plt.grid(True)

plt.savefig('U_up_direction.png')


#save_path = os.path.join('result_prob_H3_angle_H3_all',f'H3_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#save_path = os.path.join(save_file,f'{changed_parameter}_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#plt.savefig(save_path)

# Show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the X_label versus Y_label for different changed_parameter
ax.plot(angle,abs(data_direct[:,1]), 'bo--')
ax.plot(angle,angle, 'r-')


font_properties = fm.FontProperties(
    family='serif',  # Specify the font family
    style='italic',
    size=12,
    weight='bold'  # Specify the font weight (e.g., 'normal', 'bold')
)


ax.set_xlabel('Inlet velocity angle', fontproperties=font_properties)
ax.set_ylabel('Probe velocity direction', fontproperties=font_properties)
#ax.set_title(f'{fixed_parameter1}={fixed_parameter1_value} and {fixed_parameter2}={fixed_parameter2_value} for Different {changed_parameter} prob 3 to 1')

# Define custom x-axis tick positions and labels
x_tick_positions = list(range(0,91,5))  # Specify the tick positions
x_tick_labels = [str(x) for x in x_tick_positions]  # Convert positions to strings
ax.set_xticks(x_tick_positions)
ax.set_xticklabels(x_tick_labels)


# Define custom y-axis tick positions and labels
y_tick_positions = list(np.arange(0,91,5))  # Specify the tick positions
y_tick_labels = [str(y) for y in y_tick_positions]  # Convert positions to strings
ax.set_yticks(y_tick_positions)
ax.set_yticklabels(y_tick_labels)


y_min=0
y_max=90
ax.set_ylim(y_min, y_max)


# Set font size for axis tick labels (both x and y)
tick_font_size = 14  # Adjust the font size as needed
ax.tick_params(axis='both', labelsize=tick_font_size)



ax.legend(prop=font_properties)
# Turn off the legend frame
ax.get_legend().set_frame_on(False)

# Adjust space between subplots
# plt.tight_layout()

plt.grid(True)

plt.savefig('U_mid_direction.png')


#save_path = os.path.join('result_prob_H3_angle_H3_all',f'H3_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#save_path = os.path.join(save_file,f'{changed_parameter}_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#plt.savefig(save_path)

# Show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the X_label versus Y_label for different changed_parameter
ax.plot(angle,abs(data_direct[:,2]), 'bo--')
ax.plot(angle,angle, 'r-')


font_properties = fm.FontProperties(
    family='serif',  # Specify the font family
    style='italic',
    size=12,
    weight='bold'  # Specify the font weight (e.g., 'normal', 'bold')
)


ax.set_xlabel('Inlet velocity angle', fontproperties=font_properties)
ax.set_ylabel('Probe velocity direction', fontproperties=font_properties)
#ax.set_title(f'{fixed_parameter1}={fixed_parameter1_value} and {fixed_parameter2}={fixed_parameter2_value} for Different {changed_parameter} prob 3 to 1')

# Define custom x-axis tick positions and labels
x_tick_positions = list(range(0,91,5))  # Specify the tick positions
x_tick_labels = [str(x) for x in x_tick_positions]  # Convert positions to strings
ax.set_xticks(x_tick_positions)
ax.set_xticklabels(x_tick_labels)


# Define custom y-axis tick positions and labels
y_tick_positions = list(np.arange(0,91,5))  # Specify the tick positions
y_tick_labels = [str(y) for y in y_tick_positions]  # Convert positions to strings
ax.set_yticks(y_tick_positions)
ax.set_yticklabels(y_tick_labels)


y_min=0
y_max=90
ax.set_ylim(y_min, y_max)


# Set font size for axis tick labels (both x and y)
tick_font_size = 14  # Adjust the font size as needed
ax.tick_params(axis='both', labelsize=tick_font_size)



ax.legend(prop=font_properties)
# Turn off the legend frame
ax.get_legend().set_frame_on(False)

# Adjust space between subplots
# plt.tight_layout()

plt.grid(True)

plt.savefig('U_bottom_direction.png')


#save_path = os.path.join('result_prob_H3_angle_H3_all',f'H3_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#save_path = os.path.join(save_file,f'{changed_parameter}_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#plt.savefig(save_path)

# Show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the X_label versus Y_label for different changed_parameter
ax.plot(angle,abs(data_direct[:,0]-angle), 'bo--')
#ax.plot(angle,angle, 'r-')


font_properties = fm.FontProperties(
    family='serif',  # Specify the font family
    style='italic',
    size=12,
    weight='bold'  # Specify the font weight (e.g., 'normal', 'bold')
)


ax.set_xlabel('Inlet velocity angle', fontproperties=font_properties)
ax.set_ylabel('Probe velocity deviation', fontproperties=font_properties)
#ax.set_title(f'{fixed_parameter1}={fixed_parameter1_value} and {fixed_parameter2}={fixed_parameter2_value} for Different {changed_parameter} prob 3 to 1')

# Define custom x-axis tick positions and labels
x_tick_positions = list(range(0,91,5))  # Specify the tick positions
x_tick_labels = [str(x) for x in x_tick_positions]  # Convert positions to strings
ax.set_xticks(x_tick_positions)
ax.set_xticklabels(x_tick_labels)


# Define custom y-axis tick positions and labels
y_tick_positions = list(np.arange(-20,20,5))  # Specify the tick positions
y_tick_labels = [str(y) for y in y_tick_positions]  # Convert positions to strings
ax.set_yticks(y_tick_positions)
ax.set_yticklabels(y_tick_labels)


y_min=0
y_max=20
ax.set_ylim(y_min, y_max)


# Set font size for axis tick labels (both x and y)
tick_font_size = 14  # Adjust the font size as needed
ax.tick_params(axis='both', labelsize=tick_font_size)



ax.legend(prop=font_properties)
# Turn off the legend frame
ax.get_legend().set_frame_on(False)

# Adjust space between subplots
# plt.tight_layout()

plt.grid(True)

plt.savefig('U_up_dirct_deviation.png')


#save_path = os.path.join('result_prob_H3_angle_H3_all',f'H3_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#save_path = os.path.join(save_file,f'{changed_parameter}_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#plt.savefig(save_path)

# Show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the X_label versus Y_label for different changed_parameter
ax.plot(angle,abs(data_direct[:,1]-angle), 'bo--')
#ax.plot(angle,angle, 'r-')


font_properties = fm.FontProperties(
    family='serif',  # Specify the font family
    style='italic',
    size=12,
    weight='bold'  # Specify the font weight (e.g., 'normal', 'bold')
)


ax.set_xlabel('Inlet velocity angle', fontproperties=font_properties)
ax.set_ylabel('Probe velocity deviation', fontproperties=font_properties)
#ax.set_title(f'{fixed_parameter1}={fixed_parameter1_value} and {fixed_parameter2}={fixed_parameter2_value} for Different {changed_parameter} prob 3 to 1')

# Define custom x-axis tick positions and labels
x_tick_positions = list(range(0,91,5))  # Specify the tick positions
x_tick_labels = [str(x) for x in x_tick_positions]  # Convert positions to strings
ax.set_xticks(x_tick_positions)
ax.set_xticklabels(x_tick_labels)


# Define custom y-axis tick positions and labels
y_tick_positions = list(np.arange(-20,20,5))  # Specify the tick positions
y_tick_labels = [str(y) for y in y_tick_positions]  # Convert positions to strings
ax.set_yticks(y_tick_positions)
ax.set_yticklabels(y_tick_labels)


y_min=0
y_max=20
ax.set_ylim(y_min, y_max)


# Set font size for axis tick labels (both x and y)
tick_font_size = 14  # Adjust the font size as needed
ax.tick_params(axis='both', labelsize=tick_font_size)



ax.legend(prop=font_properties)
# Turn off the legend frame
ax.get_legend().set_frame_on(False)

# Adjust space between subplots
# plt.tight_layout()

plt.grid(True)

plt.savefig('U_mid_dirct_deviation.png')


#save_path = os.path.join('result_prob_H3_angle_H3_all',f'H3_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#save_path = os.path.join(save_file,f'{changed_parameter}_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#plt.savefig(save_path)

# Show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the X_label versus Y_label for different changed_parameter
ax.plot(angle,abs(data_direct[:,2]-angle), 'bo--')
#ax.plot(angle,angle, 'r-')


font_properties = fm.FontProperties(
    family='serif',  # Specify the font family
    style='italic',
    size=12,
    weight='bold'  # Specify the font weight (e.g., 'normal', 'bold')
)


ax.set_xlabel('Inlet velocity angle', fontproperties=font_properties)
ax.set_ylabel('Probe velocity deviation', fontproperties=font_properties)
#ax.set_title(f'{fixed_parameter1}={fixed_parameter1_value} and {fixed_parameter2}={fixed_parameter2_value} for Different {changed_parameter} prob 3 to 1')

# Define custom x-axis tick positions and labels
x_tick_positions = list(range(0,91,5))  # Specify the tick positions
x_tick_labels = [str(x) for x in x_tick_positions]  # Convert positions to strings
ax.set_xticks(x_tick_positions)
ax.set_xticklabels(x_tick_labels)


# Define custom y-axis tick positions and labels
y_tick_positions = list(np.arange(-20,20,5))  # Specify the tick positions
y_tick_labels = [str(y) for y in y_tick_positions]  # Convert positions to strings
ax.set_yticks(y_tick_positions)
ax.set_yticklabels(y_tick_labels)


y_min=0
y_max=20
ax.set_ylim(y_min, y_max)


# Set font size for axis tick labels (both x and y)
tick_font_size = 14  # Adjust the font size as needed
ax.tick_params(axis='both', labelsize=tick_font_size)



ax.legend(prop=font_properties)
# Turn off the legend frame
ax.get_legend().set_frame_on(False)

# Adjust space between subplots
# plt.tight_layout()

plt.grid(True)

plt.savefig('U_bottom_dirct_deviation.png')


#save_path = os.path.join('result_prob_H3_angle_H3_all',f'H3_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#save_path = os.path.join(save_file,f'{changed_parameter}_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#plt.savefig(save_path)

# Show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# plt.plot(angle,abs(data_U_x[:,0]), 'bo--')
#
# #plt.xlabel('time (s)', fontdict=font)
# plt.xlabel("angle (degree)")
#
# plt.ylabel("U_x: Up/bottom")
#
# plt.show()
# data_U_x

# %% [markdown]
# plt.plot(angle,abs(data_U_y[:,0]), 'bo--')
#
# #plt.xlabel('time (s)', fontdict=font)
# plt.xlabel("angle (degree)")
#
# plt.ylabel("U_y: Up/bottom")
#
# plt.show()
# data_U_y

# %% [markdown]
# plt.plot(angle,abs(data_U_z[:,0]), 'bo--')
#
# #plt.xlabel('time (s)', fontdict=font)
# plt.xlabel("angle (degree)")
#
# plt.ylabel("U_z: Up/bottom")
#
# plt.show()
# data_U_y

# %% [markdown]
# plt.plot(angle,abs(data_direct[:,0]), 'bo--')
#
# plt.plot(angle,angle, 'r-')
#
#
# #plt.xlabel('time (s)', fontdict=font)
# plt.xlabel("angle (degree)")
#
# plt.ylabel("U_direct: Up")
#
# plt.yticks(np.arange(min(abs(data_direct[:,0])), 1.1*max(abs(data_direct[:,0])),5))
#
# plt.xticks(np.arange(min(angle), 1.1*max(angle), 5))
#
#
# #plt.grid()
#
# plt.grid(axis = 'y')
#
# plt.savefig('U_dirct_up.png')
#
# plt.show()
#
#
# data_direct[:,0]

# %% [markdown]
# plt.plot(angle,abs(data_direct[:,1]), 'bo--')
#
# plt.plot(angle,angle, 'r-')
#
#
# #plt.xlabel('time (s)', fontdict=font)
# plt.xlabel("angle (degree)")
#
# plt.ylabel("U_direct: mid")
#
# plt.yticks(np.arange(min(abs(data_direct[:,1])), 1.1*max(abs(data_direct[:,1])),5))
#
# plt.xticks(np.arange(min(angle), 1.1*max(angle), 5))
#
#
# #plt.grid()
#
# plt.grid(axis = 'y')
#
# plt.savefig('U_dirct_mid.png')
#
# plt.show()
#
#
# data_direct[:,1]

# %% [markdown]
# plt.plot(angle,abs(data_direct[:,2]), 'bo--')
#
# plt.plot(angle,angle, 'r-')
#
#
# #plt.xlabel('time (s)', fontdict=font)
# plt.xlabel("angle (degree)")
#
# plt.ylabel("U_direct: bottom")
#
# plt.yticks(np.arange(min(abs(data_direct[:,2])), 1.1*max(abs(data_direct[:,2])),5))
#
# plt.xticks(np.arange(min(angle), 1.1*max(angle), 5))
#
#
# #plt.grid()
#
# plt.grid(axis = 'y')
#
# plt.savefig('U_dirct_bottom.png')
#
# plt.show()
#
#
# data_direct[:,2]

# %% [markdown]
# np.size(angle)
#
# dirct_U_0_05=np.zeros(np.size(angle))
# mag_U_0_to_U_ref_05=np.zeros(np.size(angle))
#
# dirct_U_0_10=np.zeros(np.size(angle))
# mag_U_0_to_U_ref_10=np.zeros(np.size(angle))
#
# U_ref_10 = 20
#
# import math
#
#
# for i in range(np.size(angle)):
#     dirct_U_0_10[i]=math.atan(data_U_0_10[i,2]/data_U_0_10[i,1])*(180/math.pi)
#
#
#
# for i in range(np.size(angle)):
#     mag_U_0_to_U_ref_10[i]=(data_U_0_10[i,0]/U_ref_10)
#
# #------------------------------------------------------------------------------------------------------
# np.size(angle)
#
# dirct_U_0=np.zeros(np.size(angle))
# mag_U_0_to_U_ref=np.zeros(np.size(angle))
#
# import math
#
#
# for i in range(np.size(angle)):
#     dirct_U_0_05[i]=math.atan(data_U_0_05[i,2]/data_U_0_05[i,1])*(180/math.pi)
#
#
#
# for i in range(np.size(angle)):
#     mag_U_0_to_U_ref_05[i]=(data_U_0_05[i,0]/U_ref_10)

# %% [markdown]
# data_U_0_10
# plt.plot(angle,abs(dirct_U_0_05), 'bo--')
#
# plt.plot(angle,angle, 'r-')
#
#
# #plt.xlabel('time (s)', fontdict=font)
# plt.xlabel("angle (degree)")
#
# plt.ylabel("U_direct: Prob0")
#
# plt.yticks(np.arange(min(abs(dirct_U_0_05)), 1.1*max(abs(dirct_U_0_05)),5))
#
# plt.xticks(np.arange(min(angle), 1.1*max(angle), 5))
#
#
# #plt.grid()
#
# plt.grid(axis = 'y')
#
# plt.savefig('U_dirct_prob0_05.png')
#
# plt.show()
#
# data_direct[:,2]
#
# dirct_U_0_05

# %% [markdown]
# plt.plot(angle,mag_U_0_to_U_ref_05, 'bo--')
#
#
# #plt.xlabel('time (s)', fontdict=font)
# plt.xlabel("angle (degree)")
#
# plt.ylabel("U_mag: U0/U_ref - 0.5(m)")
#
# plt.yticks(np.arange(min(abs(mag_U_0_to_U_ref_05)), 1.1*max(abs(mag_U_0_to_U_ref_05)),0.05))
#
# plt.xticks(np.arange(min(angle), 1.1*max(angle), 5))
#
#
# #plt.grid()
#
# plt.grid(axis = 'y')
#
# plt.savefig('U_mag_uprobo_to_uref_05.png')
#
# plt.show()
#
# data_direct[:,2]
#
# mag_U_0_to_U_ref_05

# %% [markdown]
# plt.plot(angle,abs(dirct_U_0_10), 'bo--')
#
# plt.plot(angle,angle, 'r-')
#
#
# #plt.xlabel('time (s)', fontdict=font)
# plt.xlabel("angle (degree)")
#
# plt.ylabel("U_direct: Prob0 -10 (m)")
#
# plt.yticks(np.arange(min(abs(dirct_U_0_10)), 1.1*max(abs(dirct_U_0_10)),5))
#
# plt.xticks(np.arange(min(angle), 1.1*max(angle), 5))
#
#
# #plt.grid()
#
# plt.grid(axis = 'y')
#
# plt.savefig('U_dirct_prob0_10(m).png')
#
# plt.show()
#
# data_direct[:,2]
#
# dirct_U_0_10

# %% [markdown]
# plt.plot(angle,mag_U_0_to_U_ref_10, 'bo--')
#
#
# #plt.xlabel('time (s)', fontdict=font)
# plt.xlabel("angle (degree)")
#
# plt.ylabel("U_mag: U0/U_ref - 10(m)")
#
# plt.yticks(np.arange(min(abs(mag_U_0_to_U_ref_10)), 1.1*max(abs(mag_U_0_to_U_ref_10)),0.05))
#
# plt.xticks(np.arange(min(angle), 1.1*max(angle), 5))
#
#
# #plt.grid()
#
# plt.grid(axis = 'y')
#
# plt.savefig('U_mag_uprobo_to_uref_10.png')
#
# plt.show()
#
# data_direct[:,2]
#
# mag_U_0_to_U_ref_10

# %% [markdown]
# ## real profile measured data velocity ratio

# %%
data_measured_velocity_ratio = np.loadtxt('realprofile_fig5_6_data/fig5abc.txt')
data_measured_velocity_direction = np.loadtxt('realprofile_fig5_6_data/fig6abc.txt')
data_measured_velocity_direction_deviation = np.loadtxt('realprofile_fig5_6_data/fig6def.txt')

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the X_label versus Y_label for different changed_parameter
ax.plot(data_measured_velocity_ratio[:,0],data_measured_velocity_ratio[:,2], 'bo')    

font_properties = fm.FontProperties(
    family='serif',  # Specify the font family
    style='italic',
    size=12,
    weight='bold'  # Specify the font weight (e.g., 'normal', 'bold')
)


ax.set_xlabel('Inlet velocity angle', fontproperties=font_properties)
ax.set_ylabel('Velocity magnitude ratio', fontproperties=font_properties)
#ax.set_title(f'{fixed_parameter1}={fixed_parameter1_value} and {fixed_parameter2}={fixed_parameter2_value} for Different {changed_parameter} prob 3 to 1')

# Define custom x-axis tick positions and labels
x_tick_positions = list(range(-91,91,20))  # Specify the tick positions
x_tick_labels = [str(x) for x in x_tick_positions]  # Convert positions to strings
ax.set_xticks(x_tick_positions)
ax.set_xticklabels(x_tick_labels)


# Define custom y-axis tick positions and labels
y_tick_positions = list(np.arange(0,4,0.5))  # Specify the tick positions
y_tick_labels = [str(y) for y in y_tick_positions]  # Convert positions to strings
ax.set_yticks(y_tick_positions)
ax.set_yticklabels(y_tick_labels)


x_min = -91
x_max = 91
ax.set_xlim(x_min, x_max)

y_min=0.5
y_max=3.5
ax.set_ylim(y_min, y_max)


# Set font size for axis tick labels (both x and y)
tick_font_size = 14  # Adjust the font size as needed
ax.tick_params(axis='both', labelsize=tick_font_size)



ax.legend(prop=font_properties)
# Turn off the legend frame
ax.get_legend().set_frame_on(False)

# Adjust space between subplots
# plt.tight_layout()

plt.grid(True)

plt.savefig('U_mag_up_to_bottom_measured.png')


#save_path = os.path.join('result_prob_H3_angle_H3_all',f'H3_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#save_path = os.path.join(save_file,f'{changed_parameter}_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#plt.savefig(save_path)

# Show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the first set of data with different x and y sizes
ax.plot(data_measured_velocity_ratio[:, 0], data_measured_velocity_ratio[:, 2], 'ro', label='Measured data')

# Plot the second set of data with different x and y sizes
ax.plot(angle, data_U_mag[:, 0], 'bd-', label='CFD simulation')

font_properties = fm.FontProperties(
    family='serif',
    style='italic',
    size=12,
    weight='bold'
)

ax.set_xlabel('Inlet velocity angle', fontproperties=font_properties)
ax.set_ylabel('Velocity magnitude ratio', fontproperties=font_properties)

# Define custom x-axis tick positions and labels
x_tick_positions = list(range(-90, 90, 10))
x_tick_labels = [str(x) for x in x_tick_positions]
ax.set_xticks(x_tick_positions)
ax.set_xticklabels(x_tick_labels)

# Define custom y-axis tick positions and labels
y_tick_positions = list(np.arange(0, 4, 0.5))
y_tick_labels = [str(y) for y in y_tick_positions]
ax.set_yticks(y_tick_positions)
ax.set_yticklabels(y_tick_labels)

x_min = -90
x_max = 90
ax.set_xlim(x_min, x_max)

y_min = 0.5
y_max = 3.5
ax.set_ylim(y_min, y_max)

# Set font size for axis tick labels (both x and y)
tick_font_size = 14
ax.tick_params(axis='both', labelsize=tick_font_size)

ax.legend(prop=font_properties)
ax.get_legend().set_frame_on(False)

plt.grid(True)

#plt.savefig('U_mag_up_to_bottom_measured_combine.png')
plt.show()

# %%
angle_all = np.zeros(2 * len(angle) - 1)
data_U_mag_all = np.zeros((2 * len(data_U_mag) - 1,3))


for i in range(1, len(angle)):
    angle_all[i-1] = -angle[-i]
    data_U_mag_all[i-1,0] = data_U_mag[-i,0]
    data_U_mag_all[i-1,1] = data_U_mag[-i,1]
    data_U_mag_all[i-1,2] = data_U_mag[-i,2]
    
angle_all[len(angle)-1]=angle[0]
data_U_mag_all[len(angle)-1,0] = data_U_mag[0,0]
data_U_mag_all[len(angle)-1,1] = data_U_mag[0,1]
data_U_mag_all[len(angle)-1,2] = data_U_mag[0,2]

for i in range(1, len(angle)):
    angle_all[len(angle)-1+i] = angle[i]
    data_U_mag_all[len(angle)-1+i,0] = data_U_mag[i,0]
    data_U_mag_all[len(angle)-1+i,1] = data_U_mag[i,1]
    data_U_mag_all[len(angle)-1+i,2] = data_U_mag[i,2]

# %%
data_U_mag_all
# Out:
# array([[1.04696981, 1.20540447, 0.86856307],
#        [1.18980721, 1.24770688, 0.95359513],
#        [1.40481664, 1.37646591, 1.02059675],
#        [1.63605512, 1.5024398 , 1.08893222],
#        [1.87782694, 1.58110345, 1.18766861],
#        [2.02112121, 1.61952311, 1.24797306],
#        [2.1792594 , 1.65702975, 1.31516009],
#        [2.47427611, 1.72478734, 1.43453981],
#        [2.70629992, 1.76569471, 1.53271112],
#        [2.87525583, 1.7898308 , 1.60644002],
#        [2.93244041, 1.79558772, 1.63313682],
#        [2.87525583, 1.7898308 , 1.60644002],
#        [2.70629992, 1.76569471, 1.53271112],
#        [2.47427611, 1.72478734, 1.43453981],
#        [2.1792594 , 1.65702975, 1.31516009],
#        [2.02112121, 1.61952311, 1.24797306],
#        [1.87782694, 1.58110345, 1.18766861],
#        [1.63605512, 1.5024398 , 1.08893222],
#        [1.40481664, 1.37646591, 1.02059675],
#        [1.18980721, 1.24770688, 0.95359513],
#        [1.04696981, 1.20540447, 0.86856307]])

# %%
angle_all
# Out:
# array([-89., -80., -70., -60., -50., -45., -40., -30., -20., -10.,   0.,
#         10.,  20.,  30.,  40.,  45.,  50.,  60.,  70.,  80.,  89.])

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the first set of data with different x and y sizes
ax.plot(data_measured_velocity_ratio[:, 0], data_measured_velocity_ratio[:, 2], 'ro', label='Measured data')

# Plot the second set of data with different x and y sizes
ax.plot(angle_all, data_U_mag_all[:, 0], 'bd-', label='CFD simulation')

font_properties = fm.FontProperties(
    family='serif',
    style='italic',
    size=12,
    weight='bold'
)

ax.set_xlabel('Inlet velocity angle', fontproperties=font_properties)
ax.set_ylabel('Velocity magnitude ratio', fontproperties=font_properties)

# Define custom x-axis tick positions and labels
x_tick_positions = list(range(-90, 90, 10))
x_tick_labels = [str(x) for x in x_tick_positions]
ax.set_xticks(x_tick_positions)
ax.set_xticklabels(x_tick_labels)

# Define custom y-axis tick positions and labels
y_tick_positions = list(np.arange(0, 4, 0.5))
y_tick_labels = [str(y) for y in y_tick_positions]
ax.set_yticks(y_tick_positions)
ax.set_yticklabels(y_tick_labels)

x_min = -90
x_max = 90
ax.set_xlim(x_min, x_max)

y_min = 0.5
y_max = 3.5
ax.set_ylim(y_min, y_max)

# Set font size for axis tick labels (both x and y)
tick_font_size = 14
ax.tick_params(axis='both', labelsize=tick_font_size)

ax.legend(prop=font_properties)
ax.get_legend().set_frame_on(False)

plt.grid(True)

plt.savefig('U_mag_up_to_bottom_measured_combine.png')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the first set of data with different x and y sizes
ax.plot(data_measured_velocity_ratio[:, 0], data_measured_velocity_ratio[:, 3], 'ro', label='Measured data')

# Plot the second set of data with different x and y sizes
ax.plot(angle_all, data_U_mag_all[:, 1], 'bd-', label='CFD simulation')

font_properties = fm.FontProperties(
    family='serif',
    style='italic',
    size=12,
    weight='bold'
)

ax.set_xlabel('Inlet velocity angle', fontproperties=font_properties)
ax.set_ylabel('Velocity magnitude ratio', fontproperties=font_properties)

# Define custom x-axis tick positions and labels
x_tick_positions = list(range(-90, 90, 10))
x_tick_labels = [str(x) for x in x_tick_positions]
ax.set_xticks(x_tick_positions)
ax.set_xticklabels(x_tick_labels)

# Define custom y-axis tick positions and labels
y_tick_positions = list(np.arange(0, 4, 0.5))
y_tick_labels = [str(y) for y in y_tick_positions]
ax.set_yticks(y_tick_positions)
ax.set_yticklabels(y_tick_labels)

x_min = -90
x_max = 90
ax.set_xlim(x_min, x_max)

y_min = 0.5
y_max = 3.5
ax.set_ylim(y_min, y_max)

# Set font size for axis tick labels (both x and y)
tick_font_size = 14
ax.tick_params(axis='both', labelsize=tick_font_size)

ax.legend(prop=font_properties)
ax.get_legend().set_frame_on(False)

plt.grid(True)

plt.savefig('U_mag_up_to_mid_measured_combine.png')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the first set of data with different x and y sizes
ax.plot(data_measured_velocity_ratio[:, 0], data_measured_velocity_ratio[:, 1], 'ro', label='Measured data')

# Plot the second set of data with different x and y sizes
ax.plot(angle_all, data_U_mag_all[:, 2], 'bd-', label='CFD simulation')

font_properties = fm.FontProperties(
    family='serif',
    style='italic',
    size=12,
    weight='bold'
)

ax.set_xlabel('Inlet velocity angle', fontproperties=font_properties)
ax.set_ylabel('Velocity magnitude ratio', fontproperties=font_properties)

# Define custom x-axis tick positions and labels
x_tick_positions = list(range(-90, 90, 10))
x_tick_labels = [str(x) for x in x_tick_positions]
ax.set_xticks(x_tick_positions)
ax.set_xticklabels(x_tick_labels)

# Define custom y-axis tick positions and labels
y_tick_positions = list(np.arange(0, 4, 0.5))
y_tick_labels = [str(y) for y in y_tick_positions]
ax.set_yticks(y_tick_positions)
ax.set_yticklabels(y_tick_labels)

x_min = -90
x_max = 90
ax.set_xlim(x_min, x_max)

y_min = 0.5
y_max = 3.5
ax.set_ylim(y_min, y_max)

# Set font size for axis tick labels (both x and y)
tick_font_size = 14
ax.tick_params(axis='both', labelsize=tick_font_size)

ax.legend(prop=font_properties)
ax.get_legend().set_frame_on(False)

plt.grid(True)

plt.savefig('U_mag_mid_to_bottom_measured_combine.png')
plt.show()

# %% [markdown]
# ## real profile measured data velocity direction

# %%
angle_all = np.zeros(2 * len(angle) - 1)
data_direct_all = np.zeros((2 * len(data_direct) - 1,3))


for i in range(1, len(angle)):
    angle_all[i-1] = -angle[-i]
    data_direct_all[i-1,0] = -data_direct[-i,0]
    data_direct_all[i-1,1] = -data_direct[-i,1]
    data_direct_all[i-1,2] = -data_direct[-i,2]
    
angle_all[len(angle)-1]=angle[0]
data_direct_all[len(angle)-1,0] = data_direct[0,0]
data_direct_all[len(angle)-1,1] = data_direct[0,1]
data_direct_all[len(angle)-1,2] = data_direct[0,2]

for i in range(1, len(angle)):
    angle_all[len(angle)-1+i] = angle[i]
    data_direct_all[len(angle)-1+i,0] = data_direct[i,0]
    data_direct_all[len(angle)-1+i,1] = data_direct[i,1]
    data_direct_all[len(angle)-1+i,2] = data_direct[i,2]

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the X_label versus Y_label for different changed_parameter
ax.plot(data_measured_velocity_direction[:,0],data_measured_velocity_direction[:,3], 'ro', label='Measured data')
ax.plot(angle_all,data_direct_all[:,0], 'bd-', label='CFD simulation')
ax.plot(angle_all,angle_all, 'k-', label='Inlet velocity direction')


font_properties = fm.FontProperties(
    family='serif',  # Specify the font family
    style='italic',
    size=12,
    weight='bold'  # Specify the font weight (e.g., 'normal', 'bold')
)


ax.set_xlabel('Inlet velocity angle', fontproperties=font_properties)
ax.set_ylabel('Probe velocity direction', fontproperties=font_properties)
#ax.set_title(f'{fixed_parameter1}={fixed_parameter1_value} and {fixed_parameter2}={fixed_parameter2_value} for Different {changed_parameter} prob 3 to 1')

# Define custom x-axis tick positions and labels
x_tick_positions = list(range(-90,90,10))  # Specify the tick positions
x_tick_labels = [str(x) for x in x_tick_positions]  # Convert positions to strings
ax.set_xticks(x_tick_positions)
ax.set_xticklabels(x_tick_labels)


# Define custom y-axis tick positions and labels
y_tick_positions = list(np.arange(-90,90,10))  # Specify the tick positions
y_tick_labels = [str(y) for y in y_tick_positions]  # Convert positions to strings
ax.set_yticks(y_tick_positions)
ax.set_yticklabels(y_tick_labels)


x_min = -90
x_max = 90
ax.set_xlim(x_min, x_max)

y_min=-90
y_max=90
ax.set_ylim(y_min, y_max)


# Set font size for axis tick labels (both x and y)
tick_font_size = 14  # Adjust the font size as needed
ax.tick_params(axis='both', labelsize=tick_font_size)



ax.legend(prop=font_properties)
# Turn off the legend frame
ax.get_legend().set_frame_on(False)

# Adjust space between subplots
# plt.tight_layout()

#plt.grid(True)

plt.savefig('U_up_direction_combine.png')


#save_path = os.path.join('result_prob_H3_angle_H3_all',f'H3_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#save_path = os.path.join(save_file,f'{changed_parameter}_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#plt.savefig(save_path)

# Show the plot
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the X_label versus Y_label for different changed_parameter
ax.plot(data_measured_velocity_direction[:,0],data_measured_velocity_direction[:,2], 'ro', label='Measured data')
ax.plot(angle_all,data_direct_all[:,1], 'bd-', label='CFD simulation')
ax.plot(angle_all,angle_all, 'k-', label='Inlet velocity direction')


font_properties = fm.FontProperties(
    family='serif',  # Specify the font family
    style='italic',
    size=12,
    weight='bold'  # Specify the font weight (e.g., 'normal', 'bold')
)


ax.set_xlabel('Inlet velocity angle', fontproperties=font_properties)
ax.set_ylabel('Probe velocity direction', fontproperties=font_properties)
#ax.set_title(f'{fixed_parameter1}={fixed_parameter1_value} and {fixed_parameter2}={fixed_parameter2_value} for Different {changed_parameter} prob 3 to 1')

# Define custom x-axis tick positions and labels
x_tick_positions = list(range(-90,90,10))  # Specify the tick positions
x_tick_labels = [str(x) for x in x_tick_positions]  # Convert positions to strings
ax.set_xticks(x_tick_positions)
ax.set_xticklabels(x_tick_labels)


# Define custom y-axis tick positions and labels
y_tick_positions = list(np.arange(-90,90,10))  # Specify the tick positions
y_tick_labels = [str(y) for y in y_tick_positions]  # Convert positions to strings
ax.set_yticks(y_tick_positions)
ax.set_yticklabels(y_tick_labels)


x_min = -90
x_max = 90
ax.set_xlim(x_min, x_max)

y_min=-90
y_max=90
ax.set_ylim(y_min, y_max)


# Set font size for axis tick labels (both x and y)
tick_font_size = 14  # Adjust the font size as needed
ax.tick_params(axis='both', labelsize=tick_font_size)



ax.legend(prop=font_properties)
# Turn off the legend frame
ax.get_legend().set_frame_on(False)

# Adjust space between subplots
# plt.tight_layout()

#plt.grid(True)

plt.savefig('U_mid_direction_combine.png')


#save_path = os.path.join('result_prob_H3_angle_H3_all',f'H3_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#save_path = os.path.join(save_file,f'{changed_parameter}_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#plt.savefig(save_path)

# Show the plot
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the X_label versus Y_label for different changed_parameter
ax.plot(data_measured_velocity_direction[:,0],data_measured_velocity_direction[:,1], 'ro', label='Measured data')
ax.plot(angle_all,data_direct_all[:,2], 'bd-', label='CFD simulation')
ax.plot(angle_all,angle_all, 'k-', label='Inlet velocity direction')


font_properties = fm.FontProperties(
    family='serif',  # Specify the font family
    style='italic',
    size=12,
    weight='bold'  # Specify the font weight (e.g., 'normal', 'bold')
)


ax.set_xlabel('Inlet velocity angle', fontproperties=font_properties)
ax.set_ylabel('Probe velocity direction', fontproperties=font_properties)
#ax.set_title(f'{fixed_parameter1}={fixed_parameter1_value} and {fixed_parameter2}={fixed_parameter2_value} for Different {changed_parameter} prob 3 to 1')

# Define custom x-axis tick positions and labels
x_tick_positions = list(range(-90,90,10))  # Specify the tick positions
x_tick_labels = [str(x) for x in x_tick_positions]  # Convert positions to strings
ax.set_xticks(x_tick_positions)
ax.set_xticklabels(x_tick_labels)


# Define custom y-axis tick positions and labels
y_tick_positions = list(np.arange(-90,90,10))  # Specify the tick positions
y_tick_labels = [str(y) for y in y_tick_positions]  # Convert positions to strings
ax.set_yticks(y_tick_positions)
ax.set_yticklabels(y_tick_labels)


x_min = -90
x_max = 90
ax.set_xlim(x_min, x_max)

y_min=-90
y_max=90
ax.set_ylim(y_min, y_max)


# Set font size for axis tick labels (both x and y)
tick_font_size = 14  # Adjust the font size as needed
ax.tick_params(axis='both', labelsize=tick_font_size)



ax.legend(prop=font_properties)
# Turn off the legend frame
ax.get_legend().set_frame_on(False)

# Adjust space between subplots
# plt.tight_layout()

#plt.grid(True)

plt.savefig('U_bottom_direction_combine.png')


#save_path = os.path.join('result_prob_H3_angle_H3_all',f'H3_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#save_path = os.path.join(save_file,f'{changed_parameter}_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#plt.savefig(save_path)

# Show the plot
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the X_label versus Y_label for different changed_parameter
ax.plot(data_measured_velocity_direction_deviation[:,0],abs(data_measured_velocity_direction_deviation[:,3]), 'ro', label='Measured data')
ax.plot(angle_all,abs(data_direct_all[:,0]-angle_all), 'bd-', label='CFD simulation')
#ax.plot(angle,angle, 'r-')


font_properties = fm.FontProperties(
    family='serif',  # Specify the font family
    style='italic',
    size=12,
    weight='bold'  # Specify the font weight (e.g., 'normal', 'bold')
)


ax.set_xlabel('Inlet velocity angle', fontproperties=font_properties)
ax.set_ylabel('Probe velocity deviation', fontproperties=font_properties)
#ax.set_title(f'{fixed_parameter1}={fixed_parameter1_value} and {fixed_parameter2}={fixed_parameter2_value} for Different {changed_parameter} prob 3 to 1')

# Define custom x-axis tick positions and labels
x_tick_positions = list(range(-90,90,10))  # Specify the tick positions
x_tick_labels = [str(x) for x in x_tick_positions]  # Convert positions to strings
ax.set_xticks(x_tick_positions)
ax.set_xticklabels(x_tick_labels)


# Define custom y-axis tick positions and labels
y_tick_positions = list(np.arange(0,60,10))  # Specify the tick positions
y_tick_labels = [str(y) for y in y_tick_positions]  # Convert positions to strings
ax.set_yticks(y_tick_positions)
ax.set_yticklabels(y_tick_labels)


x_min = -90
x_max = 90
ax.set_xlim(x_min, x_max)



y_min=0
y_max=60
ax.set_ylim(y_min, y_max)


# Set font size for axis tick labels (both x and y)
tick_font_size = 14  # Adjust the font size as needed
ax.tick_params(axis='both', labelsize=tick_font_size)



ax.legend(prop=font_properties)
# Turn off the legend frame
ax.get_legend().set_frame_on(False)

# Adjust space between subplots
# plt.tight_layout()

#plt.grid(True)

plt.savefig('U_up_dirct_deviation_combine.png')


#save_path = os.path.join('result_prob_H3_angle_H3_all',f'H3_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#save_path = os.path.join(save_file,f'{changed_parameter}_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#plt.savefig(save_path)

# Show the plot
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the X_label versus Y_label for different changed_parameter
ax.plot(data_measured_velocity_direction_deviation[:,0],abs(data_measured_velocity_direction_deviation[:,2]), 'ro', label='Measured data')
ax.plot(angle_all,abs(data_direct_all[:,1]-angle_all), 'bd-', label='CFD simulation')
#ax.plot(angle,angle, 'r-')


font_properties = fm.FontProperties(
    family='serif',  # Specify the font family
    style='italic',
    size=12,
    weight='bold'  # Specify the font weight (e.g., 'normal', 'bold')
)


ax.set_xlabel('Inlet velocity angle', fontproperties=font_properties)
ax.set_ylabel('Probe velocity deviation', fontproperties=font_properties)
#ax.set_title(f'{fixed_parameter1}={fixed_parameter1_value} and {fixed_parameter2}={fixed_parameter2_value} for Different {changed_parameter} prob 3 to 1')

# Define custom x-axis tick positions and labels
x_tick_positions = list(range(-90,90,10))  # Specify the tick positions
x_tick_labels = [str(x) for x in x_tick_positions]  # Convert positions to strings
ax.set_xticks(x_tick_positions)
ax.set_xticklabels(x_tick_labels)


# Define custom y-axis tick positions and labels
y_tick_positions = list(np.arange(0,60,10))  # Specify the tick positions
y_tick_labels = [str(y) for y in y_tick_positions]  # Convert positions to strings
ax.set_yticks(y_tick_positions)
ax.set_yticklabels(y_tick_labels)


x_min = -90
x_max = 90
ax.set_xlim(x_min, x_max)



y_min=0
y_max=60
ax.set_ylim(y_min, y_max)


# Set font size for axis tick labels (both x and y)
tick_font_size = 14  # Adjust the font size as needed
ax.tick_params(axis='both', labelsize=tick_font_size)



ax.legend(prop=font_properties)
# Turn off the legend frame
ax.get_legend().set_frame_on(False)

# Adjust space between subplots
# plt.tight_layout()

#plt.grid(True)

plt.savefig('U_mid_dirct_deviation_combine.png')


#save_path = os.path.join('result_prob_H3_angle_H3_all',f'H3_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#save_path = os.path.join(save_file,f'{changed_parameter}_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#plt.savefig(save_path)

# Show the plot
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the X_label versus Y_label for different changed_parameter
ax.plot(data_measured_velocity_direction_deviation[:,0],abs(data_measured_velocity_direction_deviation[:,1]), 'ro', label='Measured data')
ax.plot(angle_all,abs(data_direct_all[:,2]-angle_all), 'bd-', label='CFD simulation')
#ax.plot(angle,angle, 'r-')


font_properties = fm.FontProperties(
    family='serif',  # Specify the font family
    style='italic',
    size=12,
    weight='bold'  # Specify the font weight (e.g., 'normal', 'bold')
)


ax.set_xlabel('Inlet velocity angle', fontproperties=font_properties)
ax.set_ylabel('Probe velocity deviation', fontproperties=font_properties)
#ax.set_title(f'{fixed_parameter1}={fixed_parameter1_value} and {fixed_parameter2}={fixed_parameter2_value} for Different {changed_parameter} prob 3 to 1')

# Define custom x-axis tick positions and labels
x_tick_positions = list(range(-90,90,10))  # Specify the tick positions
x_tick_labels = [str(x) for x in x_tick_positions]  # Convert positions to strings
ax.set_xticks(x_tick_positions)
ax.set_xticklabels(x_tick_labels)


# Define custom y-axis tick positions and labels
y_tick_positions = list(np.arange(0,60,10))  # Specify the tick positions
y_tick_labels = [str(y) for y in y_tick_positions]  # Convert positions to strings
ax.set_yticks(y_tick_positions)
ax.set_yticklabels(y_tick_labels)


x_min = -90
x_max = 90
ax.set_xlim(x_min, x_max)



y_min=0
y_max=60
ax.set_ylim(y_min, y_max)


# Set font size for axis tick labels (both x and y)
tick_font_size = 14  # Adjust the font size as needed
ax.tick_params(axis='both', labelsize=tick_font_size)



ax.legend(prop=font_properties)
# Turn off the legend frame
ax.get_legend().set_frame_on(False)

# Adjust space between subplots
# plt.tight_layout()

#plt.grid(True)

plt.savefig('U_bottom_dirct_deviation_combine.png')


#save_path = os.path.join('result_prob_H3_angle_H3_all',f'H3_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#save_path = os.path.join(save_file,f'{changed_parameter}_angle_{fixed_parameter1}={fixed_parameter1_value}_and_{fixed_parameter2}={fixed_parameter2_value}.png')

#plt.savefig(save_path)

# Show the plot
plt.show()

# %%
angle_all = np.zeros(2 * len(angle) - 1)
data_U_mag_all = np.zeros((2 * len(data_U_mag) - 1,3))


for i in range(1, len(angle)):
    angle_all[i-1] = -angle[-i]
    data_U_mag_all[i-1,0] = data_U_mag[-i,0]
    data_U_mag_all[i-1,1] = data_U_mag[-i,1]
    data_U_mag_all[i-1,2] = data_U_mag[-i,2]
    
angle_all[len(angle)-1]=angle[0]
data_U_mag_all[len(angle)-1,0] = data_U_mag[0,0]
data_U_mag_all[len(angle)-1,1] = data_U_mag[0,1]
data_U_mag_all[len(angle)-1,2] = data_U_mag[0,2]

for i in range(1, len(angle)):
    angle_all[len(angle)-1+i] = angle[i]
    data_U_mag_all[len(angle)-1+i,0] = data_U_mag[i,0]
    data_U_mag_all[len(angle)-1+i,1] = data_U_mag[i,1]
    data_U_mag_all[len(angle)-1+i,2] = data_U_mag[i,2]
    
    



fig, ax = plt.subplots(figsize=(8, 6))

# Plot the first set of data with different x and y sizes
ax.plot(data_measured_velocity_ratio[:, 0], data_measured_velocity_ratio[:, 2], 'y*', markersize=10, label='Measured data')

# Plot the second set of data with different x and y sizes
ax.plot(angle_all, data_U_mag_all[:, 0], 'bd-', label='CFD simulation')

font_properties = fm.FontProperties(
    family='serif',
    style='italic',
    size=20,
    weight='bold'
)

font_properties_legend = fm.FontProperties(
    family='serif',
    style='italic',
    size=18,
    weight='bold'
)

ax.set_xlabel('Inlet wind direction on the beach (degrees)', fontproperties=font_properties)
ax.set_ylabel('Velocity speed-up ($U_{crest}/U_{toe}$)', fontproperties=font_properties)

# Define custom x-axis tick positions and labels
x_tick_positions = list(range(-90, 90, 15))
x_tick_labels = [str(x) for x in x_tick_positions]
ax.set_xticks(x_tick_positions)
ax.set_xticklabels(x_tick_labels)

# Define custom y-axis tick positions and labels
y_tick_positions = list(np.arange(0, 4, 0.5))
y_tick_labels = [str(y) for y in y_tick_positions]
ax.set_yticks(y_tick_positions)
ax.set_yticklabels(y_tick_labels)

x_min = -90
x_max = 90
ax.set_xlim(x_min, x_max)

y_min = 0.5
y_max = 3.5
ax.set_ylim(y_min, y_max)

# Set font size for axis tick labels (both x and y)
tick_font_size = 20
ax.tick_params(axis='both', labelsize=tick_font_size)

ax.legend(prop=font_properties_legend)
ax.get_legend().set_frame_on(False)

plt.grid(True)

plt.savefig('U_mag_up_to_bottom_measured_combine_NCK_conference.png')
plt.show()
